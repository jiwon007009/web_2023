# %% [markdown]
# <a href="https://colab.research.google.com/github/jiwon007009/python-project/blob/myhome/Ch04_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <span style="font-size:100%">
#
# 수업은 모두 열심히 들으셨나요?
#
# 간혹 강의에서 언급되지 않은 내용이 문제로 나올 수 있습니다.<br>
# 그럴땐 강의 내용 외 문제는 구글링을 통해 해결해주세요<br></span>
# <span style="font-size:80%">
# (구글링 또한 개발자가 갖쳐야할 역량 중에 하나랍니다 😊)
# </span>
#
# ---

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# ```다음 중 14 % 3의 계산 결과로 옳은 것을 고르세요```
#
# 1. 4
# 2. 4.6
# 3. 2
# 4. 1

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 3

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# ```다음 중 올바르지 않은 것을 고르세요```
#
# 1. float(17//3)
# 2. int(10)-9
# 3. float11/2
# 4. float(10)-2

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 잘 모르겠습니다

# %% [markdown]
# ----

# %% [markdown]
# [문제3]<br><br>
# 다음 계산식의 결괏값을 골라주세요
#
# (3 * 7 - 16) / 2 - 1

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 1.5

# %% [markdown]
# ----

# %% [markdown]
# [문제4]<br><br>
# 거듭제곱을 올바르게 표현한 식을 골라주세요
#
# 1. 2 ^^ 3
# 2. 2 ** 3
# 3. 2 ^* 3
# 4. 2 ~~ 3

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 2

# %% [markdown]
# ----

# %% [markdown]
# [문제5]<br><br>
# 목과 나머지를 함께 구하기 위해 사용할 수 있는 표현을 골라주세요
#
# 1. //
# 2. divmod()
# 3. %
# 4. /

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 2
